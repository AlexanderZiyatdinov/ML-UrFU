# %% [markdown]
# # Финальная домашняя работа
# # End-to-End Machine Learning Project
#
# ## Описание
# В данной **последней домашней работе** вам предстоит решить задачу классификации текстов на датасете AG News.
#
# Темы работы:
# - постановка задачи машинного обучения;
# - анализ данных;
# - TF-IDF и Logistic Regression;
# - нейронные сети;
# - оптимизация и SGD;
# - backpropagation;
# - трансформеры и transfer learning.

# %% [markdown]
# ## Как оценивается
#
# * За каждую верную выполненную часть +1 балл
#
# * Всего в работе 5 частей

# %% [markdown]
# ## Полезные материалы
#
# - https://huggingface.co/docs/datasets
# - https://huggingface.co/datasets/ag_news
# - https://huggingface.co/docs/transformers
# - https://scikit-learn.org/stable/documentation.html
# - https://pytorch.org/docs/stable/index.html

# %% [markdown]
# # Часть 0. Подготовка данных
#
# За эту часть баллы получить нельзя, но сделать её надо :)

# %% [markdown]
# ## Задание 1
#
# Импортируйте необходимые библиотеки.

# %%
# Ваш код здесь

# %% [markdown]
# ## Задание 2
#
# Загрузите датасет AG News.

# %%
# Ваш код здесь

# %% [markdown]
# ## Задание 3
#
# Изучите структуру датасета.
#
# Необходимо вывести:
# * Количество объектов в `train`
# * Количество объекто в `test`
# * Названия признаков
# * 3 случайных объекта

# %%
# Ваш код здесь

# %% [markdown]
# # Часть 1. Постановка задачи и анализ данных (1 балл)

# %% [markdown]
# ## Задание 1
#
# Проведите первичный анализ данных.
#
# * Посчитать количество объектов каждого класса.
# * Построить столбчатую диаграмму распределения классов.
# * Посчитать длину каждого текста.
# * Построить гистограмму длин текстов.

# %%
# Ваш код здесь

# %% [markdown]
# ## Задание 2
#
# Ответьте на вопросы о задаче, признаках и метриках.

# %% [markdown]
# ### Какая задача машинного обучения решается?
#
# Ваш ответ:

# %% [markdown]
# ### Что является объектом?
#
# Ваш ответ:

# %% [markdown]
# ### Что является признаком?
#
# Ваш ответ:

# %% [markdown]
# ### Что является целевой переменной?
#
# Ваш ответ:

# %% [markdown]
# ### Какие метрики качества, по-вашему мнению, подходят для данной задачи?
#
# Ваш ответ:

# %% [markdown]
# ## Задание 3
#
# Подготовьте данные для дальнейшего обучения.

# %%
# Ваш код здесь

# %% [markdown]
# # Часть 2. Logistic Regression + TF-IDF (1 балл)
#
# Прежде чем переходить к сложным моделям, необходимо построить качественный baseline.
#
#
# Вам, возможно, понадобятся:
#
# ```python
# TfidfVectorizer
# LogisticRegression
# classification_report
# confusion_matrix
# ```

# %% [markdown]
# ## Задание 1
#
# Преобразуйте тексты в TF-IDF признаки.

# %%
# Ваш код здесь

# %% [markdown]
# ## Задание 2
#
# Обучите Logistic Regression.

# %%
# Ваш код здесь

# %% [markdown]
# ## Задание 3
#
# Оцените качество модели.
#
# Необходимо вычислить:
#
# * Accuracy
# * Precision
# * Recall
# * F1-score

# %%
# Ваш код здесь

# %% [markdown]
# ## Задание 4
#
# Постройте confusion matrix.

# %%
# Ваш код здесь

# %% [markdown]
# # Часть 3. Нейронные сети и оптимизация (1 балл)
#
# В этой части необходимо построить собственную нейронную сеть, используя `Pytorch`:
#
# Можно использовать:
#
# ```python
# nn.Linear
# nn.ReLU
# CrossEntropyLoss
# DataLoader
# ```
#
# Или любые другие методы\классы, которые вам могут пригодиться

# %% [markdown]
# ## Задание 1
#
# Создайте `Dataset` и `DataLoader`.

# %%
# Ваш код здесь

# %% [markdown]
# ## Задание 2
#
# Реализуйте MLP.
#
# Вы можете реализовать самую-самую базу:
#
# $$Input \to Linear \to ReLU \to Linear \to Output$$

# %%
# Ваш код здесь

# %% [markdown]
# ## Задание 3
#
# Обучите модель с `SGD`.

# %%
# Ваш код здесь

# %% [markdown]
# ## Задание 4
#
# Сравните `SGD`, `Momentum` и `Adam`.
# Будет круто, если вы возьметё ещё и другие оптимайзеры.

# %%
# Ваш код здесь

# %% [markdown]
# ## Задание 5
#
# Постройте графики обучения.

# %%
# Ваш код здесь

# %% [markdown]
# # Часть 4. Backpropagation (1 балл)

# %% [markdown]
# ## Задание 1
#
# Выполните forward pass вручную.

# %%
# Ваш код здесь

# %% [markdown]
# ## Задание 2
#
# Вычислите градиенты вручную.

# %%
# Ваш код здесь

# %% [markdown]
# ## Задание 3
#
# Проверьте вычисления через Autograd.

# %%
# Ваш код здесь

# %% [markdown]
# # Часть 5. Transformers и Transfer Learning (1 балл)

# %% [markdown]
# ## Задание 1
#
# Загрузите `DistilBERT`.
#
# **Примечание**:
# Вы можете провести свой собственный эксперимент:
# - измените архитектуру модели;
# - измените гиперпараметры;
# - попробуйте другую pretrained-модель;
#
#
# Рекомендуемая модель:
#
# ```python
# distilbert-base-uncased
# ```
#
# Полезные классы:
#
# ```python
# AutoTokenizer
# AutoModelForSequenceClassification
# Trainer
# TrainingArguments
# ```

# %%
# Ваш код здесь

# %% [markdown]
# ## Задание 2
#
# Подготовьте данные.

# %%
# Ваш код здесь

# %% [markdown]
# ## Задание 3
#
# Выполните fine-tuning.

# %%
# Ваш код здесь

# %% [markdown]
# ## Задание 4
#
# Оцените качество модели.

# %%
# Ваш код здесь

# %% [markdown]
# # Итоговый анализ

# %% [markdown]
# ## Задание 1
#
# Сравните все модели. Какая лучше всех? Какая хуже всех? Почему так получилось?

# %%
# Ваш код здесь

# %% [markdown]
# ## Задание 2
#
# Напишите финальный вывод.

# %%
# Ваш код здесь
